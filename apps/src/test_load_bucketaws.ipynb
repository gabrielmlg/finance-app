# %%
import boto3
import pandas as pd

# %%
from boto3.session import Session
import io

ACCESS_KEY='AKIAXPJHEGASZIZGKQ5A'
SECRET_KEY='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'
bucket= 'balbi-finance-app'

s3 = boto3.client(
    's3', 
    region_name='us-east-1', 
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY
)

df_list = []
response = s3.list_objects(Bucket=bucket)
request_files = response["Contents"]
for file in request_files:
    obj = s3.get_object(Bucket=bucket, Key=file["Key"])
    if file["Key"].find('datasets/posicao/') >= 0:
        print('Posicao: {}'.format(file["Key"]))
        df_pos_ = pd.read_excel(io.BytesIO(obj['Body'].read()))
        df_list.append(df_pos_)
    elif file["Key"].find('datasets/extrato/Extrato.csv') >= 0:
        print('Extrato: {}'.format(file["Key"]))
        df_extrato = pd.read_csv(obj["Body"], sep=';', decimal=',')
    elif file["Key"].find('datasets/acoes/extrato_acoes.xlsx') >= 0:
        print('Extrato ações: {}'.format(file["Key"]))
        #df_extacoes = pd.read_excel(obj["Body"], sheet_name='Planilha2')
        df_extacoes = pd.read_excel(io.BytesIO(obj['Body'].read()), sheet_name='Planilha2')
        
    
    #obj_df = pd.read_csv(obj["Body"])
    #df_list.append(obj_df)

#df = pd.concat(df_list)

df_extacoes.head()
# Out:
# Extrato ações: datasets/acoes/extrato_acoes.xlsx
# Extrato: datasets/extrato/Extrato.csv
# Posicao: datasets/posicao/-PosicaoHistorico_200091-10.xls
# WARNING *** file size (60570) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-3 2.xls
# WARNING *** file size (71838) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-4 2.xls
# WARNING *** file size (71834) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-5 - cópia.xls
# WARNING *** file size (69788) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-7.xls
# WARNING *** file size (60570) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-8.xls
# WARNING *** file size (60570) not 512 + multiple of sector size (512)
# Posicao: datasets/posicao/-PosicaoHistorico_200091-9.xls
# ...

# %%
df_extrato.head()
# Out:
#           Liq         Mov                                          Descricao  \
# 0  04/06/2020  04/06/2020  * PROV * DEBITO CBLC IRRF S/ RENDIMENTO DE BTC...
# 1  04/06/2020  04/06/2020  * PROV * CrŽdito Ref. Taxa de Remunera‹o BTC ...
# 2  01/06/2020  28/05/2020  OPERA‚ÍES EM BOLSA PR 28/05/2020 NOTA N¼ 22035030
# 3  28/05/2020  28/05/2020                     TED - RECEBIMENTO DE TED - SPB
# 4  28/05/2020  28/05/2020               RENDIMENTOS DE CLIENTES CNES11 S/ 11
#
#      Valor    Saldo
# 0    -0.01    58.23
# 1     0.06    58.24
# 2 -8419.82    58.18
# 3  7000.00  8478.00
# 4     1.81  1478.00

# %%
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN                                                NaN        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# ..          ...                                                ...        ...
# 123         NaN                                                NaN        NaN
# 124         NaN                         XP Investimentos CCTVM S/A        NaN
# 125         NaN                                                NaN        NaN
# 126         NaN  Praia de Botafogo, 501 - Sala 601 A1\nBotafogo...        NaN
# 127         NaN                                                NaN        NaN
#
# ...

# %%
session = Session(aws_access_key_id=ACCESS_KEY,
                  aws_secret_access_key=SECRET_KEY)
s3 = session.resource('s3')
app_bucket = s3.Bucket('balbi-finance-app')

for s3_file in app_bucket.objects.all():
#    print(s3_file.key)
    if s3_file.key.find('datasets/posicao/') >= 0:
        print('Posicao: {}'.format(s3_file.key))
    elif s3_file.key.find('datasets/extrato/Extrato.csv') >= 0:
        print('Extrato: {}'.format(s3_file.key))
    elif s3_file.key.find('datasets/acoes/extrato_acoes.xlsx') >= 0:
        print('Extrato ações: {}'.format(s3_file.key))
# Out:
# Extrato ações: datasets/acoes/extrato_acoes.xlsx
# Extrato: datasets/extrato/Extrato.csv
# Posicao: datasets/posicao/-PosicaoHistorico_200091-10.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-3 2.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-4 2.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-5 - cópia.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-7.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-8.xls
# Posicao: datasets/posicao/-PosicaoHistorico_200091-9.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-10.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-11.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-12.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-13.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-14.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-15.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-16.xls
# Posicao: datasets/posicao/PosicaoHistorico_200091-17.xls
# ...
